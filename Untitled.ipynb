# %% [markdown]
# ## Assignment 1: Write an ipython notebook that demonstrates visually in a data-driven way the Central Limit Theorem.
#
# ### (On-class practice)

# %%
from __future__ import print_function
import numpy as np
import pylab as pl
from scipy.optimize import curve_fit, minimize
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.random.seed(1000)

# %%
chisq = np.random.chisquare(100,20)
chisq
# Out:
# array([  88.42052431,  103.92584878,   95.15366243,  104.92469252,
#         107.95856822,   92.92677283,   83.41056641,   93.72052471,
#          97.39503287,  109.61570333,  118.35911165,   86.06422743,
#         105.18391849,  112.86370768,   91.77872254,   94.03017939,
#          98.36001566,  100.5107861 ,   95.10349488,  128.97805658])

# %%
pl.hist(chisq, bins = 30)
# Out:
# (array([ 1.,  1.,  0.,  1.,  0.,  1.,  3.,  2.,  0.,  2.,  0.,  1.,  0.,
#          1.,  2.,  0.,  1.,  1.,  0.,  1.,  0.,  0.,  0.,  1.,  0.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([  83.41056641,   84.92948275,   86.44839909,   87.96731543,
#           89.48623177,   91.00514811,   92.52406445,   94.04298079,
#           95.56189712,   97.08081346,   98.5997298 ,  100.11864614,
#          101.63756248,  103.15647882,  104.67539516,  106.1943115 ,
#          107.71322784,  109.23214418,  110.75106051,  112.26997685,
#          113.78889319,  115.30780953,  116.82672587,  118.34564221,
#          119.86455855,  121.38347489,  122.90239123,  124.42130756,
#          125.9402239 ,  127.45914024,  128.97805658]),
#  <a list of 30 Patch objects>)

# %%
size = (2000/ np.array(range(1,101)))

# %%
chidist = []
for i in range(0,len(size)):
    chidist.append(np.random.chisquare(100, size[i]))

# %%
type(chidist[0])
# Out:
# numpy.ndarray

# %%
chimeans = []
for i in range(0,len(size)):
    chimeans.append(chidist[i].mean())

# %%
pl.scatter(size, chimeans)
pl.title('Sample Mean (Chisquare Distribution) VS Sample Size')

# %% [markdown]
# ### (Instructions from HW3_fb55, contain chi-squared distribution, possion distribution, normal distribution, bionmial distribution, and cauchy distribution)

# %%
# Chi-squared 
distributions = ['chisq']
mean = 100
df = mean
md = {}
md['chisq'] = np.random.chisquare(df, size = 100)
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 100.51, standard deviation: 14.41

# %%
size = (2000 / (np.array(range(1, 100)))).astype(int)
print (size, size.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['chisq'] = {} 
for n in size:
    md['chisq'][n] = np.random.chisquare(df, size = n)  

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(size), max(size)], [df, df], 'k')

# %%
# Poisson
distributions = ['pois']
mean =100
df =mean
md = {}
md['pois'] = np.random.poisson(df, size = 100)
pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("pois mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(), md['pois'].std()))
# Out:
# pois mean: 100.93, standard deviation: 11.09

# %%
size = (2000 / (np.array(range(1, 100)))).astype(int)
print (size, size.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['pois'] = {} 
for n in size:
    md['pois'][n] = np.random.chisquare(df, size = n)
    md['pois']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        axchisq_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Poisson', fontsize=18)
        axchisq_mu_n.plot([min(size), max(size)], [df, df], 'k')

# %%
# Normal
distributions = ['normal']
mean =100
df =mean
md = {}
md['normal'] = np.random.poisson(df, size = 100)
pl.hist(md['normal'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("normal mean: %.2f, standard deviation: %.2f"%(md['normal'].mean(), md['normal'].std()))
# Out:
# normal mean: 99.65, standard deviation: 10.17

# %%
size = (2000 / (np.array(range(1, 100)))).astype(int)
print (size, size.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['normal'] = {} 
for n in size:
    md['normal'][n] = np.random.chisquare(df, size = n)
    md['normal']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['normal']:
    if not type(nn) == str:
        md['normal']['means'][nn] = md['normal'][nn].mean()
        axchisq_mu_n.plot(nn, md['normal']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Normal', fontsize=18)
        axchisq_mu_n.plot([min(size), max(size)], [df, df], 'k')

# %%
# Binomial
distributions = ['binomial']
mean =100
df =mean
md = {}
md['binomial'] = np.random.poisson(df, size = 100)
pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# binomial mean: 100.71, standard deviation: 9.88

# %%
size = (2000 / (np.array(range(1, 100)))).astype(int)
print (size, size.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['binomial'] = {} 
for n in size:
    md['binomial'][n] = np.random.chisquare(df, size = n)
    md['binomial']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        axchisq_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Bionmial', fontsize=18)
        axchisq_mu_n.plot([min(size), max(size)], [df, df], 'k')

# %%
# Cauchy
distributions = ['cauchy']
mean =100
df =mean
md = {}
md['cauchy'] = np.random.poisson(df, size = 100)
pl.hist(md['cauchy'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("cauchy mean: %.2f, standard deviation: %.2f"%(md['cauchy'].mean(), md['cauchy'].std()))
# Out:
# cauchy mean: 100.10, standard deviation: 10.29

# %%
size = (2000 / (np.array(range(1, 100)))).astype(int)
print (size, size.shape)
# Out:
# (array([2000, 1000,  666,  500,  400,  333,  285,  250,  222,  200,  181,
#         166,  153,  142,  133,  125,  117,  111,  105,  100,   95,   90,
#          86,   83,   80,   76,   74,   71,   68,   66,   64,   62,   60,
#          58,   57,   55,   54,   52,   51,   50,   48,   47,   46,   45,
#          44,   43,   42,   41,   40,   40,   39,   38,   37,   37,   36,
#          35,   35,   34,   33,   33,   32,   32,   31,   31,   30,   30,
#          29,   29,   28,   28,   28,   27,   27,   27,   26,   26,   25,
#          25,   25,   25,   24,   24,   24,   23,   23,   23,   22,   22,
#          22,   22,   21,   21,   21,   21,   21,   20,   20,   20,   20]), (99,))

# %%
md['cauchy'] = {} 
for n in size:
    md['cauchy'][n] = np.random.chisquare(df, size = n)
    md['cauchy']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['cauchy']:
    if not type(nn) == str:
        md['cauchy']['means'][nn] = md['cauchy'][nn].mean()
        axchisq_mu_n.plot(nn, md['cauchy']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('cauchy', fontsize=18)
        axchisq_mu_n.plot([min(size), max(size)], [df, df], 'k')

# %% [markdown]
# ## Assignment 2: Set up the work for data-driven inference based on CitiBike data.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import pylab as pl
# %matplotlib inline

# %%
if os.getenv ('PUI2016') is None:
    print("Must set env variable PUI2016")
if os.getenv ('PUIDATA') is None:
    print("Must set env variable PUI2016")

# %%
def getCitiBikeCSV(datestring):
    
    print ("Downloading", datestring)
    if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv"):
        if os.path.isfile(datestring + "-citibike-tripdata.csv"):
            os.system("mv " + datestring + "-citibike-tripdata.csv " + os.getenv("PUIDATA"))
        else:
            if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.zip"):
                if not os.path.isfile(datestring + "-citibike-tripdata.zip"):
                    os.system("curl -O https://s3.amazonaws.com/tripdata/" + datestring + "-citibike-tripdata.zip")
                os.system("mv " + datestring + "-citibike-tripdata.zip " + os.getenv("PUIDATA"))

            os.system("unzip " + os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.zip")

            if '2014' in datestring or '2013' in datestring:
                    os.system("mv " + datestring[:4] + '-' +  datestring[4:] + 
                              "\ -\ Citi\ Bike\ trip\ data.csv " + datestring + "-citibike-tripdata.csv")
            os.system("mv " + datestring + "-citibike-tripdata.csv " + os.getenv("PUIDATA"))

            print("File in place, you can continue.")
            
            if not os.path.isfile(os.getenv("PUIDATA") + "/" + datestring + "-citibike-tripdata.csv"):
                print("WARNING!!! something is wrong: the file is not there!")
    else:
        print("File in place, you can continue.")

# %%
datestring = "201501"
getCitiBikeCSV(datestring)
# Out:
# ('Downloading', '201501')
# File in place, you can continue.

# %%
df=pd.read_csv(os.getenv("PUIDATA") + "/" + datestring + '-citibike-tripdata.csv').dropna()

# %%
df['date'] = pd.to_datetime(df['starttime'])

# %%
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1346  1/1/2015 0:01  1/1/2015 0:24               455
# 1           363  1/1/2015 0:02  1/1/2015 0:08               434
# 2           346  1/1/2015 0:04  1/1/2015 0:10               491
# 3           182  1/1/2015 0:04  1/1/2015 0:07               384
# 4           969  1/1/2015 0:05  1/1/2015 0:21               474
#
#         start station name  start station latitude  start station longitude  \
# 0          1 Ave & E 44 St               40.750020               -73.969053
# 1          9 Ave & W 18 St               40.743174               -74.003664
# 2     E 24 St & Park Ave S               40.740964               -73.986022
# 3  Fulton St & Waverly Ave               40.683178               -73.965964
# 4          5 Ave & E 29 St               40.745168               -73.986831
#
#    end station id             end station name  end station latitude  \
# ...

# %%
df.columns
# Out:
# Index([u'tripduration', u'starttime', u'stoptime', u'start station id',
#        u'start station name', u'start station latitude',
#        u'start station longitude', u'end station id', u'end station name',
#        u'end station latitude', u'end station longitude', u'bikeid',
#        u'usertype', u'birth year', u'gender', u'date'],
#       dtype='object')

# %%
df.drop(['starttime', 'stoptime', 'start station id',
       'start station name', 'start station latitude',
       'start station longitude', 'end station id', 'end station name',
       'end station latitude', 'end station longitude', 'bikeid', 'usertype',
       'birth year','gender'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    tripduration                date
# 0          1346 2015-01-01 00:01:00
# 1           363 2015-01-01 00:02:00
# 2           346 2015-01-01 00:04:00
# 3           182 2015-01-01 00:04:00
# 4           969 2015-01-01 00:05:00

# %% [markdown]
# ## Question to figure out: Was September the most favourite month for biking in 2015?

# %% [markdown]
# ## Null hypothesis: mean of # of bikings in September was either equal to or less than that of any other month in 2015.
#
# ## Alternative hypothesis: mean of # of bikings in September was greater than that of any other month in 2015.

# %% [markdown]
# ## I use a significance level $\alpha=0.05$

# %%
plt.figure(figsize=(8,4))


counts_j = df.date[df.tripduration].groupby([df.date.dt.month==January]).count().plot(kind="bar", color='SteelBlue')

ax = counts_j



ax.xaxis.set_ticklabels(['January','February','March','April','May','June','July','Augest','September','October','November','December'], fontsize=10)
ax.set_ylabel ("Monthly tripduration")
ax.set_xlabel ("Month")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-97-19879fbcdb5b> in <module>()
#       1 plt.figure(figsize=(8,4))
#       2
# ----> 3 counts_j = df.date[df.tripduration].groupby([df.date.dt.month==January]).count().plot(kind="bar", color='SteelBlue')
#       4
#       5 ax = counts_j
#
# NameError: name 'January' is not defined

# %% [markdown]
# ### Null hypothesis: the new bus route takes equal or greater time to complete than that of the old one (i.e. NRT - ORT >= 0)
# ### Alternative hypothesis: the new bus route takes less time to complete than that of the old one (i.e. NRT - ORT < 0)
# ### Confidence level: $\alpha=0.05$

# %%
data = !curl -O https://raw.githubusercontent.com/fedhere/PUI2016_fb55/master/Lab3_fb55/times.txt

# %%
data_1 = pd.read_csv('times.txt', header = None)
data_1.mean()
# Out:
# 0    34.466162
# dtype: float64

# %%
mean_pop = data_1.mean()
mean_sample = 36
sigma = 6

# %%
### $ Z = \frac{\mu_{pop} - \mu_{sample}}{\sigma / \sqrt{N}} $
Z_test = (mean_pop-mean_sample)/(sigma/np.sqrt(len(data_1)))
Z_test
# Out:
# 0   -2.556397
# dtype: float64

# %% [markdown]
# ### Conclusion: since Z_test is greater than 2, we reject the null hypothesis. i.e. new bus route takes less time to complete (than the old route), at a confidence level of 95%.
